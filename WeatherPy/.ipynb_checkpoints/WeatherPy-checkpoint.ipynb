# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
# This library is useful when you need to work with location-based data and want to associate geographic coordinates with city names for further analysis or visualization tasks.
from citipy import citipy
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
#generate random latitude values within a specific range
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
print(f"Number of cities in the list:{len(cities)}")
# Out:
# tazovsky
# Number of cities in the list:602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
import json
# Set the API base URL
url ="https://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"
query_url= f"{url}&units={units}&appid={weather_api_key}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    
    # Create endpoint URL with each city
    city_url =query_url+city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
    
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
    
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
     #If an error is experienced, skip the city
    except Exception as err:
        print("City not found. Skipping...")
        print(Exception, err)
        pass
    
    # pause to avoid rate limiting
    time.sleep(1)

 #Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(city_data)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tazovsky
# Processing Record 2 of Set 1 | mount pearl
# Processing Record 3 of Set 1 | paulden
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | wailua homesteads
# Processing Record 6 of Set 1 | vernon
# Processing Record 7 of Set 1 | west island
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | santa cruz
# Processing Record 12 of Set 1 | mejit
# Processing Record 13 of Set 1 | polyarnyy
# Processing Record 14 of Set 1 | papatowai
# Processing Record 15 of Set 1 | contai
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | utrik
# Processing Record 19 of Set 1 | bethel
# Processing Record 20 of Set 1 | nuku'alofa
# Processing Record 21 of Set 1 | north bend
# Processing Record 22 of Set 1 | kasempa
# Processing Record 23 of Set 1 | stanley
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | aswan
# Processing Record 26 of Set 1 | yoloten
# Processing Record 27 of Set 1 | kataragama
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 28 of Set 1 | ugoofaaru
# Processing Record 29 of Set 1 | alo
# Processing Record 30 of Set 1 | blackmans bay
# Processing Record 31 of Set 1 | port mathurin
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | waitangi
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | kerikeri
# Processing Record 36 of Set 1 | colonia
# Processing Record 37 of Set 1 | magadi
# Processing Record 38 of Set 1 | trairi
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | mount isa
# Processing Record 41 of Set 1 | zavoronezhskoye
# Processing Record 42 of Set 1 | piacabucu
# Processing Record 43 of Set 1 | crane
# Processing Record 44 of Set 1 | kapuskasing
# Processing Record 45 of Set 1 | alice springs
# Processing Record 46 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 1 | adamstown
# Processing Record 48 of Set 1 | viedma
# Processing Record 49 of Set 1 | badger
# Processing Record 50 of Set 1 | iskateley
# Processing Record 0 of Set 2 | hithadhoo
# Processing Record 1 of Set 2 | ciudad melchor muzquiz
# Processing Record 2 of Set 2 | al-hamdaniya
# Processing Record 3 of Set 2 | kodok
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 4 of Set 2 | le vauclin
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | saipan
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | whitehorse
# Processing Record 10 of Set 2 | alaghsas
# Processing Record 11 of Set 2 | callao
# Processing Record 12 of Set 2 | lihue
# Processing Record 13 of Set 2 | afaahiti
# Processing Record 14 of Set 2 | nogliki
# Processing Record 15 of Set 2 | sishui
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 9 of Set 5 | urangan
# Processing Record 10 of Set 5 | st. john's
# Processing Record 11 of Set 5 | kurumkan
# Processing Record 12 of Set 5 | langsa
# Processing Record 13 of Set 5 | sydney
# Processing Record 14 of Set 5 | masuda
# Processing Record 15 of Set 5 | okha
# Processing Record 16 of Set 5 | zhangatas
# Processing Record 17 of Set 5 | esmeralda
# Processing Record 18 of Set 5 | karamay
# Processing Record 19 of Set 5 | ulaangom
# Processing Record 20 of Set 5 | zouerate
# Processing Record 21 of Set 5 | carbonear
# Processing Record 22 of Set 5 | east end
# Processing Record 23 of Set 5 | gangtok
# Processing Record 24 of Set 5 | margate
# Processing Record 25 of Set 5 | anna regina
# Processing Record 26 of Set 5 | waat
# Processing Record 27 of Set 5 | dudinka
# Processing Record 28 of Set 5 | nuuk
# Processing Record 29 of Set 5 | mataram
# Processing Record 30 of Set 5 | oamaru
# Processing Record 31 of Set 5 | baardheere
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | naukseni
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 34 of Set 5 | fisterra
# Processing Record 35 of Set 5 | pochinok
# Processing Record 36 of Set 5 | darzab
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | roma
# Processing Record 39 of Set 5 | nyrob
# Processing Record 40 of Set 5 | uxbridge
# Processing Record 41 of Set 5 | nar'yan-mar
# Processing Record 42 of Set 5 | goundi
# Processing Record 43 of Set 5 | middle island
# Processing Record 44 of Set 5 | fallon
# Processing Record 45 of Set 5 | lobujya
# Processing Record 46 of Set 5 | diu
# Processing Record 47 of Set 5 | tokoroa
# Processing Record 48 of Set 5 | weno
# Processing Record 49 of Set 5 | oshawa
# Processing Record 0 of Set 6 | chonchi
# Processing Record 1 of Set 6 | vyksa
# Processing Record 2 of Set 6 | remire-montjoly
# Processing Record 3 of Set 6 | sitka
# Processing Record 4 of Set 6 | kalach
# Processing Record 5 of Set 6 | itoman
# Processing Record 6 of Set 6 | natal
# Processing Record 7 of Set 6 | sierra grande
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | great falls
# Processing Record 10 of Set 6 | la'ie
# Processing Record 11 of Set 6 | codrington
# Processing Record 12 of Set 6 | brits
# Processing Record 13 of Set 6 | jiazi
# Processing Record 14 of Set 6 | juegang
# Processing Record 15 of Set 6 | rikaze
# Processing Record 16 of Set 6 | cape coast
# Processing Record 17 of Set 6 | huarmey
# Processing Record 18 of Set 6 | kirovsk
# Processing Record 19 of Set 6 | schwarzenbach an der saale
# Processing Record 20 of Set 6 | choma
# Processing Record 21 of Set 6 | puerto quijarro
# Processing Record 22 of Set 6 | verkhnevilyuysk
# Processing Record 23 of Set 6 | cidreira
# Processing Record 24 of Set 6 | mahina
# Processing Record 25 of Set 6 | ust-nera
# Processing Record 26 of Set 6 | anadyr
# Processing Record 27 of Set 6 | salamanca
# Processing Record 28 of Set 6 | charters towers
# Processing Record 29 of Set 6 | peniche
# Processing Record 30 of Set 6 | ilhabela
# Processing Record 31 of Set 6 | kirakira
# Processing Record 32 of Set 6 | san jose village
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 33 of Set 6 | cannonvale
# Processing Record 34 of Set 6 | burao
# Processing Record 35 of Set 6 | nabire
# Processing Record 36 of Set 6 | mormugao
# Processing Record 37 of Set 6 | watsa
# Processing Record 38 of Set 6 | porbandar
# Processing Record 39 of Set 6 | vorgashor
# Processing Record 40 of Set 6 | san antonio
# Processing Record 41 of Set 6 | uturoa
# Processing Record 42 of Set 6 | guercif
# Processing Record 43 of Set 6 | bilecik
# Processing Record 44 of Set 6 | senanga
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | gadzhiyevo
# Processing Record 47 of Set 6 | pacific grove
# Processing Record 48 of Set 6 | quellon
# Processing Record 49 of Set 6 | island harbour
# Processing Record 0 of Set 7 | hammerfest
# Processing Record 1 of Set 7 | salalah
# Processing Record 2 of Set 7 | al-`ula
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 3 of Set 7 | byron bay
# Processing Record 4 of Set 7 | sumbawa besar
# Processing Record 5 of Set 7 | iguape
# Processing Record 6 of Set 7 | newman
# Processing Record 7 of Set 7 | jalgaon jamod
# Processing Record 8 of Set 7 | sungai penuh
# Processing Record 9 of Set 7 | bubaque
# Processing Record 10 of Set 7 | i-n-salah
# Processing Record 11 of Set 7 | zahirabad
# Processing Record 12 of Set 7 | hilo
# Processing Record 13 of Set 7 | bhan
# Processing Record 14 of Set 7 | chandler
# Processing Record 15 of Set 7 | constantia
# Processing Record 16 of Set 7 | cobija
# Processing Record 17 of Set 7 | puerto san carlos
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 18 of Set 7 | amga
# Processing Record 19 of Set 7 | nafada
# Processing Record 20 of Set 7 | susuman
# Processing Record 21 of Set 7 | taksimo
# Processing Record 22 of Set 7 | ust-tsilma
# Processing Record 23 of Set 7 | aykhal
# Processing Record 24 of Set 7 | glubokoye
# Processing Record 25 of Set 7 | chernyshevskiy
# Processing Record 26 of Set 7 | erdenet
# Processing Record 27 of Set 7 | fale old settlement
# Processing Record 28 of Set 7 | egilsstadir
# Processing Record 29 of Set 7 | jiwani
# Processing Record 30 of Set 7 | buellton
# Processing Record 31 of Set 7 | urucara
# Processing Record 32 of Set 7 | sampit
# Processing Record 33 of Set 7 | shenjiamen
# Processing Record 34 of Set 7 | floro
# Processing Record 35 of Set 7 | nyurba
# Processing Record 36 of Set 7 | princeville
# Processing Record 37 of Set 7 | brokopondo
# Processing Record 38 of Set 7 | fuvahmulah
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 39 of Set 7 | isangel
# Processing Record 40 of Set 7 | san jose de jachal
# Processing Record 41 of Set 7 | tangalle
# Processing Record 42 of Set 7 | tura
# Processing Record 43 of Set 7 | darien
# Processing Record 44 of Set 7 | sola
# Processing Record 45 of Set 7 | bao loc
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record
# Processing Record 24 of Set 9 | peruibe
# Processing Record 25 of Set 9 | slawharad
# Processing Record 26 of Set 9 | bardai
# Processing Record 27 of Set 9 | dizangue
# Processing Record 28 of Set 9 | merizo village
# Processing Record 29 of Set 9 | mitu
# Processing Record 30 of Set 9 | boa vista
# Processing Record 31 of Set 9 | phillip island
# Processing Record 32 of Set 9 | raymond terrace
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | mao
# Processing Record 35 of Set 9 | burley
# Processing Record 36 of Set 9 | pitimbu
# Processing Record 37 of Set 9 | 'ohonua
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 38 of Set 9 | phan rang-thap cham
# Processing Record 39 of Set 9 | vallenar
# Processing Record 40 of Set 9 | walvis bay
# Processing Record 41 of Set 9 | myeik
# Processing Record 42 of Set 9 | santa ana
# Processing Record 43 of Set 9 | lethem
# Processing Record 44 of Set 9 | kzyltu
# Processing Record 45 of Set 9 | ribadeo
# Processing Record 46 of Set 9 | masterton
# Processing Record 47 of Set 9 | lamu
# Processing Record 48 of Set 9 | taltal
# Processing Record 49 of Set 9 | nagqu
# Processing Record 0 of Set 10 | labytnangi
# Processing Record 1 of Set 10 | tabou
# Processing Record 2 of Set 10 | kuching
# Processing Record 3 of Set 10 | sikandra
# Processing Record 4 of Set 10 | kendari
# Processing Record 5 of Set 10 | prince rupert
# Processing Record 6 of Set 10 | woodland
# Processing Record 7 of Set 10 | papao
# Processing Record 8 of Set 10 | sakti
# Processing Record 9 of Set 10 | cabedelo
# Processing Record 10 of Set 10 | saudarkrokur
# Processing Record 11 of Set 10 | el-tor
# Processing Record 12 of Set 10 | gamba
# Processing Record 13 of Set 10 | motueka
# Processing Record 14 of Set 10 | formosa do rio preto
# Processing Record 15 of Set 10 | tazacorte
# Processing Record 16 of Set 10 | harrisonburg
# Processing Record 17 of Set 10 | paracatu
# Processing Record 18 of Set 10 | svobodnyy
# Processing Record 19 of Set 10 | cizre
# Processing Record 20 of Set 10 | novobod
# Processing Record 21 of Set 10 | kindia
# Processing Record 22 of Set 10 | havre
# Processing Record 23 of Set 10 | jining
# Processing Record 24 of Set 10 | medicine hat
# Processing Record 25 of Set 10 | namie
# Processing Record 26 of Set 10 | bozhou
# Processing Record 27 of Set 10 | eureka
# Processing Record 28 of Set 10 | thohoyandou
# Processing Record 29 of Set 10 | ushtobe
# Processing Record 30 of Set 10 | howrah
# Processing Record 31 of Set 10 | zangguy
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 32 of Set 10 | palikir - national government center
# Processing Record 33 of Set 10 | kwale
# Processing Record 34 of Set 10 | hirado
# Processing Record 35 of Set 10 | alavus
# Processing Record 36 of Set 10 | springs
# Processing Record 37 of Set 10 | jawf al maqbabah
# Processing Record 38 of Set 10 | cronulla
# Processing Record 39 of Set 10 | geraldton
# Processing Record 40 of Set 10 | chiili
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 41 of Set 10 | obo
# Processing Record 42 of Set 10 | birjand
# Processing Record 43 of Set 10 | meulaboh
# Processing Record 44 of Set 10 | hotan
# Processing Record 45 of Set 10 | east london
# Processing Record 46 of Set 10 | kas
# Processing Record 47 of Set 10 | bereznik
# Processing Record 48 of Set 10 | kyshtovka
# Processing Record 49 of Set 10 | impfondo
# Processing Record 0 of Set 11 | lucas
# Processing Record 1 of Set 11 | minggang
# Processing Record 2 of Set 11 | childress
# Processing Record 3 of Set 11 | bechar
# Processing Record 4 of Set 11 | kosciuszko national park
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 5 of Set 11 | benito garcia (el zorrillo)
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 6 of Set 11 | chinde
# Processing Record 7 of Set 11 | tashtagol
# Processing Record 8 of Set 11 | wewak
# Processing Record 9 of Set 11 | tosontsengel
# Processing Record 10 of Set 11 | tsiolkovskiy
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 11 of Set 11 | yartsevo
# Processing Record 12 of Set 11 | chekmagush
# Processing Record 13 of Set 11 | umm kaddadah
# Processing Record 14 of Set 11 | ryotsu-minato
# Processing Record 15 of Set 11 | adh dhibiyah
# Processing Record 16 of Set 11 | sinabang
# Processing Record 17 of Set 11 | praia da vitoria
# Processing Record 18 of Set 11 | znamenskoye
# Processing Record 19 of Set 11 | ambovombe
# Processing Record 20 of Set 11 | lockwood
# Processing Record 21 of Set 11 | sarangani
# Processing Record 22 of Set 11 | victoria point
# Processing Record 23 of Set 11 | al jumum
# Processing Record 24 of Set 11 | mpika
# Processing Record 25 of Set 11 | pimenta bueno
# Processing Record 26 of Set 11 | tindouf
# Processing Record 27 of Set 11 | palmer
# Processing Record 28 of Set 11 | jieshou
# Processing Record 29 of Set 11 | teshi old town
# Processing Record 30 of Set 11 | canutama
# Processing Record 31 of Set 11 | escuinapa
# Processing Record 32 of Set 11 | puerto la cruz
# Processing Record 33 of Set 11 | bikin
# Processing Record 34 of Set 11 | puerto aysen
# Processing Record 35 of Set 11 | lundazi
# Processing Record 36 of Set 11 | cidade velha
# Processing Record 37 of Set 11 | guozhen
# Processing Record 38 of Set 11 | west busselton
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 39 of Set 11 | trincomalee
# Processing Record 40 of Set 11 | bealanana
# Processing Record 41 of Set 11 | lubang
# Processing Record 42 of Set 11 | goundam
# Processing Record 43 of Set 11 | mukalla
# Processing Record 44 of Set 11 | chapada dos guimaraes
# Processing Record 45 of Set 11 | chom bueng
# Processing Record 46 of Set 11 | la ronge
# Processing Record 47 of Set 11 | kitale
# Processing Record 48 of Set 11 | kirensk
# Processing Record 49 of Set 11 | hechuan
# Processing Record 0 of Set 12 | jalalabad
# Processing Record 1 of Set 12 | tayu
# Processing Record 2 of Set 12 | kitgum
# Processing Record 3 of Set 12 | karasburg
# Processing Record 4 of Set 12 | naples manor
# Processing Record 5 of Set 12 | kolpashevo
# Processing Record 6 of Set 12 | pyshma
# Processing Record 7 of Set 12 | luderitz
# Processing Record 8 of Set 12 | cricova
# Processing Record 9 of Set 12 | port blair
# Processing Record 10 of Set 12 | viransehir
# Processing Record 11 of Set 12 | manokwari
# Processing Record 12 of Set 12 | little cayman
# City not found. Skipping...
# <class 'Exception'> 'coord'
# Processing Record 13 of Set 12 | aracati
# Processing Record 14 of Set 12 | bodo
# Processing Record 15 of Set 12 | starobaltachevo
# Processing Record 16 of Set 12 | dunedin
# Processing Record 17 of Set 12 | pathalgaon
# Processing Record 18 of Set 12 | vila do maio
# Processing Record 19 of Set 12 | tagiura
# Processing Record 20 of Set 12 | lascano
# Processing Record 21 of Set 12 | kabalo
# Processing Record 22 of Set 12 | sunne
# Processing Record 23 of Set 12 | rosarito
# Processing Record 24 of Set 12 | barra de santo antonio
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | recani
# Processing Record 27 of Set 12 | aioun
# Processing Record 28 of Set 12 | taguatinga
# Processing Record 29 of Set 12 | yuxia
# Processing Record 30 of Set 12 | zhezqazghan
# Processing Record 31 of Set 12 | mikhnevo
# Processing Record 32 of Set 12 | timaru
# Processing Record 33 of Set 12 | ukata
# Processing Record 34 of Set 12 | salinas
# Processing Record 35 of Set 12 | iturama
# Processing Record 36 of Set 12 | achinsk
# Processing Record 37 of Set 12 | sodra sandby
# Processing Record 38 of Set 12 | san patricio
# Processing Record 39 of Set 12 | al qusayr
# Processing Record 40 of Set 12 | novodvinsk
# Processing Record 41 of Set 12 | zhangjiakou shi xuanhua qu
# Processing Record 42 of Set 12 | sao felix do xingu
# Processing Record 43 of Set 12 | kargasok
# Processing Record 44 of Set 12 | pariaman
# Processing Record 45 of Set 12 | namdrik
# Processing Record 46 of Set 12 | tokar
# Processing Record 47 of Set 12 | poronaysk
# Processing Record 48 of Set 12 | shahzadpur
# Processing Record 49 of Set 12 | sainyabuli
# Processing Record 0 of Set 13 | saint-joseph
# Processing Record 1 of Set 13 | teluknaga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# [{'City': 'tazovsky', 'Lat': 67.4667, 'Lng': 78.7, 'Max Temp': 65.01, 'Humidity': 52, 'Cloudiness': 88, 'Wind Speed': 14.34, 'Country': 'RU', 'Date': 1722764684}, {'City': 'mount pearl', 'Lat': 47.5166, 'Lng': -52.7813, 'Max Temp': 66.54, 'Humidity': 92, 'Cloudiness': 75, 'Wind Speed': 14.97, 'Country': 'CA', 'Date': 1722764685}, {'City': 'paulden', 'Lat': 34.8856, 'Lng': -112.4682, 'Max Temp': 73.17, 'Humidity': 65, 'Cloudiness': 12, 'Wind Speed': 3, 'Country': 'US', 'Date': 1722764687}, {'City': 'yellowknife', 'Lat': 62.456, 'Lng': -114.3525, 'Max Temp': 60.42, 'Humidity': 77, 'Cloudiness': 75, 'Wind Speed': 5.75, 'Country': 'CA', 'Date': 1722764419}, {'City': 'wailua homesteads', 'Lat': 22.0669, 'Lng': -159.378, 'Max Temp': 77.79, 'Humidity': 89, 'Cloudiness': 20, 'Wind Speed': 10.36, 'Country': 'US', 'Date': 1722764689}, {'City': 'vernon', 'Lat': 50.2581, 'Lng': -119.2691, 'Max Temp': 76.3, 'Humidity': 45, 'Cloudiness': 100, 'Wind Speed': 6.91, 'Country': 'CA', 'Date': 1722764476}, {'City': 'west island', 'Lat': -12.1568, 'Lng': 96.8225, 'Max Temp': 82.38, 'Humidity': 61, 'Cloudiness
ind Speed': 4.61, 'Country': 'US', 'Date': 1722764707}, {'City': 'kasempa', 'Lat': -13.4584, 'Lng': 25.8338, 'Max Temp': 83.77, 'Humidity': 13, 'Cloudiness': 6, 'Wind Speed': 7.02, 'Country': 'ZM', 'Date': 1722764708}, {'City': 'stanley', 'Lat': 54.868, 'Lng': -1.6985, 'Max Temp': 60.82, 'Humidity': 77, 'Cloudiness': 20, 'Wind Speed': 8.05, 'Country': 'GB', 'Date': 1722764710}, {'City': 'albany', 'Lat': 42.6001, 'Lng': -73.9662, 'Max Temp': 71.55, 'Humidity': 63, 'Cloudiness': 57, 'Wind Speed': 2.98, 'Country': 'US', 'Date': 172276471 ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data, columns=['City','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date'])
# Show Record Count
city_data_df.count()
# Out:
# City          576
# Lat           576
# Lng           576
# Max Temp      576
# Humidity      576
# Cloudiness    576
# Wind Speed    576
# Country       576
# Date          576
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           tazovsky  67.4667   78.7000     65.01        52          88
# 1        mount pearl  47.5166  -52.7813     66.54        92          75
# 2            paulden  34.8856 -112.4682     73.17        65          12
# 3        yellowknife  62.4560 -114.3525     60.42        77          75
# 4  wailua homesteads  22.0669 -159.3780     77.79        89          20
#
#    Wind Speed Country        Date
# 0       14.34      RU  1722764684
# 1       14.97      CA  1722764685
# 2        3.00      US  1722764687
# 3        5.75      CA  1722764419
# 4       10.36      US  1722764689

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x = 'Lat', y = 'Max Temp', s = 100); 

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Latitude_to_MaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x = 'Lat', y = 'Humidity', s = 100)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Latitude_to_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x = 'Lat', y = 'Cloudiness', s = 100)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Latitude_to_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x = 'Lat', y = 'Wind Speed', s = 100)

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Latitude_to_Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, title):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the linear regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the line equation on the plot
    plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=15, color="red")
    
    # Add labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    print(f"The r-value is: {rvalue}")
    # Display the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           tazovsky  67.4667   78.7000     65.01        52          88
# 1        mount pearl  47.5166  -52.7813     66.54        92          75
# 2            paulden  34.8856 -112.4682     73.17        65          12
# 3        yellowknife  62.4560 -114.3525     60.42        77          75
# 4  wailua homesteads  22.0669 -159.3780     77.79        89          20
#
#    Wind Speed Country        Date
# 0       14.34      RU  1722764684
# 1       14.97      CA  1722764685
# 2        3.00      US  1722764687
# 3        5.75      CA  1722764419
# 4       10.36      US  1722764689

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                            City      Lat      Lng  Max Temp  Humidity  \
# 6                   west island -12.1568  96.8225     82.38        61
# 7   edinburgh of the seven seas -37.0676 -12.3116     55.54        87
# 8             port-aux-francais -49.3500  70.2167     34.41        89
# 9                    bredasdorp -34.5322  20.0403     50.49        78
# 10                   santa cruz -17.8000 -63.1667     72.86        88
#
#     Cloudiness  Wind Speed Country        Date
# 6           42        8.05      CC  1722764691
# 7           87       30.33      SH  1722764692
# 8           93       38.92      TF  1722764693
# 9          100       18.70      ZA  1722764695
# 10          40        8.05      BO  1722764696

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Max Temp']).astype(float)
x_label = 'Latitude'
y_label = 'Max Temperature (F)'
title = 'Northern Hemisphere - Max Temp vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Temperature_to_Latitude Speed 1.png")
# Out:
# The r-value is: -0.5704347535336538

# %%
# Linear regression on Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Max Temp']).astype(float)
x_label = 'Latitude'
y_label = 'Max Temperature (F)'
title = 'Southern Hemisphere - Max Temp vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Temperature_to_Latitude Speed 2.png")
# Out:
# The r-value is: 0.821900806871143

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Humidity']).astype(float)
x_label = 'Latitude'
y_label = 'Humidity (%)'
title = 'Northern Hemisphere - Humidity  vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Humidity_to_Latitude Speed 1.png")
# Out:
# The r-value is: -0.10682501233642282

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Humidity']).astype(float)
x_label = 'Latitude'
y_label = 'Humidity (%)'
title = 'Southern Hemisphere - Max Temp vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Humidity_to_Latitude Speed 2.png")
# Out:
# The r-value is: -0.16544282136939764

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Cloudiness']).astype(float)
x_label = 'Latitude'
y_label = 'Cloudiness (%)'
title = 'Northern Hemisphere - Cloudiness vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Cloudiness_to_Latitude Speed 1.png")
# Out:
# The r-value is: -0.11005354163877994

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Cloudiness']).astype(float)
x_label = 'Latitude'
y_label = 'Cloudiness (%)'
title = 'Southern Hemisphere - Cloudiness vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Cloudiness_to_Latitude Speed 2.png")
# Out:
# The r-value is: -0.30296018159348653

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = pd.to_numeric(northern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_hemi_df['Wind Speed']).astype(float)
x_label = 'Latitude'
y_label = 'Wind Speed (mph)'
title = 'Northern Hemisphere - Wind Speed vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Wind Speed_to_Latitude Speed 1.png")
# Out:
# The r-value is: -0.005470967560918764

# %%
# Southern Hemisphere
x_values = pd.to_numeric(southern_hemi_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_hemi_df['Wind Speed']).astype(float)
x_label = 'Latitude'
y_label = 'Wind Speed (mph)'
title = 'Southern Hemisphere - Wind Speed vs. Latitude Linear Regression'
create_linear_regression_plot(x_values, y_values, x_label, y_label, title)
plt.savefig("output_data/Wind Speed_to_Latitude Speed 2.png")
# Out:
# The r-value is: -0.07305213356912588

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
